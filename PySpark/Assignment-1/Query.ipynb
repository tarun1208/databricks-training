# %%
df= spark.read.csv("/Volumes/workspace/default/databricks2027/full_employee_data.csv",header=True,inferSchema=True)
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 1. Select only emp_name and salary.

# %%
from pyspark.sql.functions import col
df.select(col("emp_name"),col("salary")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 2. Select emp_id, emp_name, and department.

# %%
df.select(col("emp_id"),col("emp_name"),col("department")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 3. Select city, designation, and salary.

# %%
df.select(col("city"),col("designation"),col("salary")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 4. Select all employees from only IT department with selected columns.

# %%
df.select(col("emp_id"),col("emp_name"),col("department"),col("salary")).filter(col("department")=="IT").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 5. Select emp_name, joining_date, and salary.

# %%
df.select(col("emp_name"),col("joining_date"),col("salary")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 6. Select first 5 columns from dataframe.

# %%
df.select("emp_id","emp_name","age","city","designation").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 7. Select employees whose salary column only.

# %%
df.select(col("emp_id"),col("emp_name"),col("salary")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 8. Select emp_name and city for employees from Hyderabad.

# %%
df.select(col("emp_name"),col("city")).filter(col("city") == "Hyderabad").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>city</th></tr></thead><tbody><tr><td>Sravan</td><td>Hyderabad</td></tr><tr><td>Meena</td><td>Hyderabad</td></tr><tr><td>Divya</td><td>Hyderabad</td></tr><tr><td>Swathi</td><td>Hyderabad</td></tr><tr><td>Deepika</td><td>Hyderabad</td></tr><tr><td>Asha</td><td>Hyderabad</td></tr><tr><td>Sowmya</td><td>Hyderabad</td></tr><tr><td>Shilpa</td><td>Hyderabad</td></tr><tr><td>Anu</td><td>Hyderabad</td></tr></tbody></table></div>

# %% [markdown]
# 9. Select designation and department.

# %%
df.select(col("emp_name"),col("designation"),col("department")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 10. Select all columns except joining_date.

# %%
df.select("emp_id","emp_name","age","city","designation","salary","department").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 11. Display emp_name as employee_name.

# %%
df.select(col("emp_name").alias("employee_name")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 12. Display salary as monthly_salary.

# %%
df.select(col("salary").alias("monthly_salary")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 13. Display department as dept.

# %%
df.select(col("department").alias("dept")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 14. Display joining_date as doj.

# %%
df.select(col("joining_date").alias("doj")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 15. Select emp_name as name and city as location.

# %%
df.select(col("emp_name").alias("name"),
          col("city").alias("location")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 16. Display designation as job_role.

# %%
df.select(col("designation").alias("job_role")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 17. Display age as employee_age.

# %%
df.select(col("age").alias("employee_age")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 18.Select multiple columns using aliases.

# %%
df.select(col("emp_id").alias("employee_id"),
          col("emp_name").alias("employee_name"),
          col("city").alias("employee_city"),
          col("salary").alias("employee_salary"),
          col("department").alias("employee_department"),
          col("designation").alias("employee_designation"),
          col("joining_date").alias("employee_joining_date")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 19. Display salary as emp_salary and department as emp_dept.

# %%
df.select(col("salary").alias("emp_salary"),
          col("department").alias("emp_dept")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 20. Display city as work_location.

# %%
df.select(col("city").alias("work_location")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 21. Filter employees whose salary is greater than 70000.

# %%
df.select(col("emp_id"),col("emp_name"),col("salary")).filter(col("salary") > 70000).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 22. Filter employees from Hyderabad.

# %%
df.select(col("emp_id"),col("emp_name"),col("city")).filter(col("city") == "Hyderabad").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>city</th></tr></thead><tbody><tr><td>1</td><td>Sravan</td><td>Hyderabad</td></tr><tr><td>7</td><td>Meena</td><td>Hyderabad</td></tr><tr><td>13</td><td>Divya</td><td>Hyderabad</td></tr><tr><td>19</td><td>Swathi</td><td>Hyderabad</td></tr><tr><td>24</td><td>Deepika</td><td>Hyderabad</td></tr><tr><td>30</td><td>Asha</td><td>Hyderabad</td></tr><tr><td>36</td><td>Sowmya</td><td>Hyderabad</td></tr><tr><td>42</td><td>Shilpa</td><td>Hyderabad</td></tr><tr><td>48</td><td>Anu</td><td>Hyderabad</td></tr></tbody></table></div>

# %% [markdown]
# 23. Filter employees whose age is less than 25.

# %%
df.select(col("emp_id"),col("emp_name"),col("age")).filter(col("age") < 25).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>age</th></tr></thead><tbody><tr><td>3</td><td>Priya</td><td>24</td></tr><tr><td>9</td><td>Pooja</td><td>23</td></tr><tr><td>13</td><td>Divya</td><td>24</td></tr><tr><td>21</td><td>Bhavana</td><td>22</td></tr><tr><td>26</td><td>Neha</td><td>24</td></tr><tr><td>30</td><td>Asha</td><td>23</td></tr><tr><td>36</td><td>Sowmya</td><td>24</td></tr><tr><td>45</td><td>Abhi</td><td>24</td></tr><tr><td>48</td><td>Anu</td><td>23</td></tr></tbody></table></div>

# %% [markdown]
# 24. Filter employees from IT department.

# %%
df.select(col("emp_id"),col("emp_name"),col("department")).filter(col("department") == "IT").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 25. Filter employees whose designation is Developer.

# %%
df.select(col("emp_id"),col("emp_name"),col("designation")).filter(col("designation") == "Developer").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>designation</th></tr></thead><tbody><tr><td>6</td><td>Arjun</td><td>Developer</td></tr><tr><td>14</td><td>Suresh</td><td>Developer</td></tr><tr><td>19</td><td>Swathi</td><td>Developer</td></tr><tr><td>25</td><td>Tarun</td><td>Developer</td></tr><tr><td>34</td><td>Ishita</td><td>Developer</td></tr><tr><td>41</td><td>Karthik</td><td>Developer</td></tr><tr><td>46</td><td>Nikitha</td><td>Developer</td></tr></tbody></table></div>

# %% [markdown]
# 26. Filter employees whose salary is between 50000 and 80000.

# %%
df.select(col("emp_id"),col("emp_name"),col("salary")).filter(col("salary").between(50000,80000)).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 27. Filter employees whose city is Bangalore.

# %%
df.select(col("emp_id"),col("emp_name"),col("city")).filter(col("city")=="Bangalore").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>city</th></tr></thead><tbody><tr><td>2</td><td>Ravi</td><td>Bangalore</td></tr><tr><td>8</td><td>Rahul</td><td>Bangalore</td></tr><tr><td>16</td><td>Mahesh</td><td>Bangalore</td></tr><tr><td>25</td><td>Tarun</td><td>Bangalore</td></tr><tr><td>31</td><td>Vinay</td><td>Bangalore</td></tr><tr><td>37</td><td>Chandu</td><td>Bangalore</td></tr><tr><td>43</td><td>Yash</td><td>Bangalore</td></tr><tr><td>49</td><td>Sandeep</td><td>Bangalore</td></tr></tbody></table></div>

# %% [markdown]
# 28. Filter employees who joined after 2022-01-01.

# %%
df.select(col("emp_id"),col("emp_name"),col("joining_date")).filter(col("joining_date") > "2022-01-01").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 29. Filter employees whose age is greater than 30.

# %%
df.filter(col("age")>30).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 30. Filter employees whose salary is less than 50000.

# %%
df.filter(col("salary")< 50000).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 31. Filter employees from Chennai and salary greater than 60000.

# %%
df.filter((col("city") == "Chennai") & (col("salary")>60000)).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>age</th><th>city</th><th>designation</th><th>salary</th><th>joining_date</th><th>department</th></tr></thead><tbody><tr><td>14</td><td>Suresh</td><td>29</td><td>Chennai</td><td>Developer</td><td>68000</td><td>2021-01-21</td><td>IT</td></tr><tr><td>20</td><td>Ajay</td><td>34</td><td>Chennai</td><td>Lead</td><td>93000</td><td>2018-04-22</td><td>IT</td></tr><tr><td>50</td><td>Pallavi</td><td>27</td><td>Chennai</td><td>Engineer</td><td>65000</td><td>2020-12-09</td><td>IT</td></tr></tbody></table></div>

# %% [markdown]
# 32. Filter employees from Mumbai or Pune.

# %%
df.filter((col("city")== "Mumbai") | (col("city")=="Pune")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 33. Filter employees whose name starts with 'S'.

# %%
df.filter(col("emp_name").startswith("S")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 34. Filter employees whose name ends with 'a'.

# %%
df.filter(col("emp_name").endswith("a")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 35. Filter employees whose department is HR.

# %%
df.filter(col("department")=="HR").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 36. Filter employees whose designation contains 'Engineer'.

# %%
df.filter(col("designation")=="Engineer").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>age</th><th>city</th><th>designation</th><th>salary</th><th>joining_date</th><th>department</th></tr></thead><tbody><tr><td>18</td><td>Naresh</td><td>28</td><td>Delhi</td><td>Engineer</td><td>62000</td><td>2021-05-17</td><td>IT</td></tr><tr><td>31</td><td>Vinay</td><td>29</td><td>Bangalore</td><td>Engineer</td><td>67000</td><td>2020-09-19</td><td>IT</td></tr><tr><td>50</td><td>Pallavi</td><td>27</td><td>Chennai</td><td>Engineer</td><td>65000</td><td>2020-12-09</td><td>IT</td></tr></tbody></table></div>

# %% [markdown]
# 37. Filter employees whose city is not Hyderabad.

# %%
df.filter(col("city") != "Hyderabad").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 38. Filter employees aged between 25 and 30.

# %%
df.filter(col("age").between(25,30)).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 39. Filter employees with salary greater than 90000.

# %%
df.filter(col("salary")>90000).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 40. Filter employees from Support department.

# %%
df.filter(col("department") == "Support").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 41. Rename emp_name to employee_name.

# %%
df.withColumnRenamed("emp_name","employee_name").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 42. Rename department to dept.

# %%
df.withColumnRenamed("department","dept").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 43. Rename joining_date to doj.

# %%
df.withColumnRenamed("joining_date","doj").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 44. Rename salary to monthly_salary.

# %%
df.withColumnRenamed("salary","monthly_salary").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 45. Rename designation to job_role.

# %%
df.withColumnRenamed("designation","job_role").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 46. Rename city to work_location.

# %%
df.withColumnRenamed("city","work_location").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 47. Rename age to employee_age.

# %%
df.withColumnRenamed("age","employee_age").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 48. Rename multiple columns one by one.

# %%
df.withColumnRenamed("emp_id", "employee_id") \
  .withColumnRenamed("emp_name", "employee_name") \
  .withColumnRenamed("age", "employee_age") \
  .withColumnRenamed("city", "work_location") \
  .withColumnRenamed("designation", "job_role") \
  .withColumnRenamed("salary", "monthly_salary") \
  .withColumnRenamed("joining_date", "doj") \
  .withColumnRenamed("department", "department_name") \
  .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 49. Rename emp_id to employee_id.

# %%
df.withColumnRenamed("emp_id", "employee_id").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 50. Rename department to business_unit.

# %%
df.withColumnRenamed("department","business_unit").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 51. Create bonus column as 10% of salary.

# %%
df.withColumn("bonus",col("salary") * 0.10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 52. Create annual_salary column.

# %%
df.withColumn("annual_salary",col("salary") *12).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 53. Create tax column as 5% of salary.

# %%
df.withColumn("tax",col("salary")*0.05).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 54. Create updated_salary by adding 5000.

# %%
df.withColumn("updated_salary",col("salary")+5000).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 55. Create salary_category column:
# - High
# - Medium
# - Low

# %%
from pyspark.sql.functions import when
df.withColumn("salary_category", when(col("salary") >= 80000, "High").when(col("salary") >= 50000, "Medium").otherwise("Low")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 56. Create age_group column:
# - Young
# - Adult

# %%
df.withColumn("age_group", when(col("age")>30, "Young").when(col("age")<=30,"adult")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 57. Create location column by combining city and department.

# %%
from pyspark.sql.functions import concat
df.withColumn("location", concat( col("city"), col("department"))).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import concat_ws
df.withColumn("location", concat_ws("-",col("city"), col("department"))).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 58. Create increment_salary column with 15% hike.

# %%
df.withColumn("increment_salary",col("salary")*0.15).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 59. Create experience_status column based on joining year.

# %%
from pyspark.sql.functions import year, current_date
df.withColumn("experience_status",year(current_date()) - year(col("joining_date"))).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 60. Create name_length column using employee name.

# %%
from pyspark.sql.functions import length
df.withColumn("name_length",length(col("emp_name"))).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 61. Create is_high_salary column using condition.

# %%
df.withColumn("is_high_salary",
              when(col("salary")>=80000,"yes")
              .otherwise("no")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 62. Create joining_year column from joining_date.

# %%
df.withColumn("joining_year",year(col("joining_date"))).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 63. Create salary_after_tax column.

# %%
df.withColumn("salary_after_tax",col("salary")*0.05).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 64. Create department_code column.

# %%
from pyspark.sql.functions import substring
df.withColumn("department_code",substring(df.department,1,3)).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 65. Create double_salary column.

# %%
df.withColumn("double_salary",df.salary*2).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 66. Convert salary to string datatype.

# %%
df.withColumn("salary",col("salary").cast("string")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 67. Convert age to double datatype.

# %%
df.withColumn("age",col("age").cast("double")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 68. Convert joining_date to date datatype.

# %%
df.withColumn("joining_date",col("joining_date").cast("date")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 69. Convert emp_id to string datatype.

# %%
df.withColumn("emp_id",col("emp_id").cast("string")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 70. Convert salary to integer datatype.

# %%
df.withColumn("salary",df.salary.cast("integer")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 71. Convert age to string datatype.

# %%
df.withColumn("age",df.age.cast("string")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 72. Convert joining_date to timestamp datatype.

# %%
df.withColumn("joining_date",df.joining_date.cast("timestamp")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 73. Convert salary to float datatype.

# %%
df.withColumn("salary",df.salary.cast("float")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 74. Convert emp_id to long datatype.

# %%
df.withColumn("emp_id",col("emp_id").cast("long")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 75. Convert multiple columns into different datatypes.

# %%
df.withColumn("salary",col("salary").cast("string"))\
    .withColumn("age",col("age").cast("double"))\
    .withColumn("joining_date",col("joining_date").cast("timestamp"))\
    .withColumn("emp_id",col("emp_id").cast("long"))\
    .display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 76. Sort employees by salary ascending.

# %%
df.orderBy("salary").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 77. Sort employees by salary descending.

# %%
df.orderBy(df.salary.desc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 78. Sort employees by age descending.

# %%
from pyspark.sql.functions import desc
df.orderBy(col("age").desc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 79. Sort employees by emp_name ascending.

# %%
df.orderBy("emp_name").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 80. Sort employees by city and salary descending.

# %%
df.orderBy("city",df.salary.desc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 81. Sort employees by joining_date.

# %%
df.orderBy("joining_date").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 82. Sort employees by department.

# %%
df.orderBy("department").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 83. Sort employees by designation descending.

# %%
df.orderBy(df.designation.desc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 84. Sort employees first by city then age.

# %%
df.orderBy("city","age").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 85. Sort employees by salary and limit top 10.

# %%
df.orderBy("salary").limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 86. Sort employees by emp_id descending.

# %%
df.orderBy(df.emp_id.desc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 87. Sort employees from IT department by salary descending.

# %%
df.filter(df.department == "IT")\
      .orderBy(col("salary").desc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 88. Sort employees by joining_date descending.

# %%
df.orderBy(col("joining_date").desc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 89. Sort employees alphabetically by emp_name.

# %%
df.orderBy("emp_name").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 90. Sort employees by multiple columns.

# %%
df.orderBy("department", col("salary").desc()).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 91. Display first 5 records.

# %%
df.limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 92. Display top 10 employees.

# %%
df.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 93. Display first 3 employees from IT department.

# %%
df.filter(col("department")=='IT').limit(3).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>age</th><th>city</th><th>designation</th><th>salary</th><th>joining_date</th><th>department</th></tr></thead><tbody><tr><td>1</td><td>Sravan</td><td>25</td><td>Hyderabad</td><td>Data Engineer</td><td>55000</td><td>2023-01-15</td><td>IT</td></tr><tr><td>2</td><td>Ravi</td><td>28</td><td>Bangalore</td><td>Software Engineer</td><td>72000</td><td>2022-11-10</td><td>IT</td></tr><tr><td>6</td><td>Arjun</td><td>26</td><td>Delhi</td><td>Developer</td><td>61000</td><td>2022-07-25</td><td>IT</td></tr></tbody></table></div>

# %% [markdown]
# 94. Display top 5 highest salary employees.

# %%
df.orderBy(df.salary.desc()).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 95. Display lowest 5 salary employees.

# %%
df.orderBy("salary").limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 96. Display first 7 rows after sorting by age.

# %%
df.orderBy(df.age).limit(7).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 97. Display first 2 employees from Hyderabad.

# %%
df.filter(col("city")=='Hyderabad').limit(2).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>age</th><th>city</th><th>designation</th><th>salary</th><th>joining_date</th><th>department</th></tr></thead><tbody><tr><td>1</td><td>Sravan</td><td>25</td><td>Hyderabad</td><td>Data Engineer</td><td>55000</td><td>2023-01-15</td><td>IT</td></tr><tr><td>7</td><td>Meena</td><td>29</td><td>Hyderabad</td><td>Tester</td><td>53000</td><td>2021-12-11</td><td>QA</td></tr></tbody></table></div>

# %% [markdown]
# 98. Display first 15 records from dataframe.

# %%
df.limit(15).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 99. Display top 5 youngest employees.

# %%
df.orderBy(df.age).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# 100. Display first 8 employees after filtering salary > 60000

# %%
df.filter(col("salary")>60000).limit(8).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
